# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Data/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='*', color='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size=0.3)
#X_train, X_test, y_train, y_test = train_test_split(df.age, df.bought_insurance, test_size=0.3, random_state=42)

# %%
print(X_test)
# Out:
#     age
# 8    62
# 1    25
# 25   54
# 0    22
# 26   23
# 14   49
# 11   28
# 20   21
# 12   27

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predicted = model.predict(X_test)

# %%
print(f'type of predicted values {type(y_predicted)} num of dimension {y_predicted.ndim} \n {y_predicted} \n {y_test}')
# Out:
# type of predicted values <class 'numpy.ndarray'> num of dimension 1
#  [1 0 1 0 0 1 0 0 0]
#  8     1
# 1     0
# 25    1
# 0     0
# 26    0
# 14    1
# 11    0
# 20    0
# 12    0
# Name: bought_insurance, dtype: int64

# %%
model.predict_proba(X_test)
# Out:
# array([[0.07599985, 0.92400015],
#        [0.7457143 , 0.2542857 ],
#        [0.15119575, 0.84880425],
#        [0.79667756, 0.20332244],
#        [0.78058282, 0.21941718],
#        [0.22403614, 0.77596386],
#        [0.68699573, 0.31300427],
#        [0.81187624, 0.18812376],
#        [0.70738187, 0.29261813]])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.coef_
# Out:
# array([[0.09659094]])

# %%
model.intercept_
# Out:
# array([-3.49065769])

# %%
import math
def sigmoid(x):
    return 1/(1+math.exp(-x))

# %%
def predict_func(age):
    x = 0.096 * age - 3.49
    y_pred = sigmoid(x)
    return y_pred

# %%
predict_func(43)
# Out:
# 0.6543012180520054
